# %%
# imports
import pandas as pd

# %%
# loading data
f1 = open("test-set_videos-captions.txt", "r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-d935a1f8a484> in <module>()
# ----> 1 f1 = open("test-set_videos-captions.txt", "r")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test-set_videos-captions.txt'
